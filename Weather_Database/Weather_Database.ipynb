# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import linregress

# %%
# create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)
lat_lngs= zip(lats, lngs)
lat_lngs

# %%
#Add the Latitudes and Longitudes to a list.
coordinates = list(lat_lngs)

# %%
#pull citipy
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 741

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f2498ebfe0a1a951c5b13297bc26a8f1

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "salalah"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=f2498ebfe0a1a951c5b13297bc26a8f1&q=salalah

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "salalah"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":54.09,"lat":17.02},"weather":[{"id":800,"main":"Clear","description":"clear sky","icon":"01n"}],"base":"stations","main":{"temp":78.8,"feels_like":75.72,"temp_min":78.8,"temp_max":78.8,"pressure":1009,"humidity":34},"visibility":10000,"wind":{"speed":4.7,"deg":20},"clouds":{"all":0},"dt":1603052799,"sys":{"type":1,"id":7562,"country":"OM","sunrise":1603073842,"sunset":1603115967},"timezone":14400,"id":286621,"name":"Salalah","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': 54.09, 'lat': 17.02},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01n'}],
#  'base': 'stations',
#  'main': {'temp': 78.8,
#   'feels_like': 75.72,
#   'temp_min': 78.8,
#   'temp_max': 78.8,
#   'pressure': 1009,
#   'humidity': 34},
#  'visibility': 10000,
#  'wind': {'speed': 4.7, 'deg': 20},
#  'clouds': {'all': 0},
#  'dt': 1603052799,
#  'sys': {'type': 1,
#   'id': 7562,
#   'country': 'OM',
#   'sunrise': 1603073842,
#   'sunset': 1603115967},
#  'timezone': 14400,
#  'id': 286621,
#  'name': 'Salalah',
#  'cod': 200}

# %%
# Get the JSON data.
salalah_data = city_weather.json()

# %%
lat = salalah_data["coord"]["lat"]
lng = salalah_data["coord"]["lon"]
max_temp = salalah_data["main"]["temp_max"]
humidity = salalah_data["main"]["humidity"]
clouds = salalah_data["clouds"]["all"]
wind = salalah_data["wind"]["speed"]
current_description = salalah_data['weather'][0]['description']
print(lat, lng, max_temp, humidity, clouds, wind, current_description)
# Out:
# 17.02 54.09 78.8 34 0 4.7 clear sky

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | afyonkarahisar
# Processing Record 2 of Set 1 | lagoa
# Processing Record 3 of Set 1 | mitsamiouli
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | ribeira grande
# Processing Record 6 of Set 1 | la palma
# Processing Record 7 of Set 1 | torbay
# Processing Record 8 of Set 1 | bonavista
# Processing Record 9 of Set 1 | nuuk
# Processing Record 10 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 1 | dedenevo
# Processing Record 12 of Set 1 | sayat
# Processing Record 13 of Set 1 | tabou
# Processing Record 14 of Set 1 | arlit
# Processing Record 15 of Set 1 | victoria
# Processing Record 16 of Set 1 | skibbereen
# Processing Record 17 of Set 1 | gazanjyk
# Processing Record 18 of Set 1 | krasnoselkup
# Processing Record 19 of Set 1 | hobyo
# Processing Record 20 of Set 1 | semirom
# Processing Record 21 of Set 1 | jesup
# ...

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                City    Lat    Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Afyonkarahisar  38.75  30.67     60.33        72         100        3.18
# 1             Lagoa  39.05 -27.98     62.74        67          70       18.25
# 2       Mitsamiouli -11.38  43.28     78.58        76           3        8.28
# 3           Ushuaia -54.80 -68.30     41.00        80          75       29.97
# 4    Ribeira Grande  38.52 -28.70     62.60        72          40       19.46
# ..              ...    ...    ...       ...       ...         ...         ...
# 686         Crotone  39.09  17.12     63.57        66          60        8.79
# 687        Ilhabela -23.78 -45.36     71.35        81          81       11.99
# 688         Itarema  -2.92 -39.92     81.30        69          93       18.03
# 689     Kamalapuram  14.58  78.65     75.31        92         100        3.96
# 690       Marinette  45.10 -87.63     44.60        36           1        5.82
#
# ...

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
